# %%
import pandas as pd

# %%
teams = pd.read_csv('teams.csv')
players = pd.read_csv('players.csv')
games = pd.read_csv('games.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 teams = pd.read_csv('teams.csv')
#       2 players = pd.read_csv('players.csv')
# ----> 3 game_stats = pd.read_csv('game_stats.csv')
#
# ...

# %%
teams
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 teams
#
# NameError: name 'teams' is not defined

# %%
players
# Out:
#     player_id  team_id       player_name position  age exp injury_status  \
# 0           1        1    Michael Wilson       WR   24   2           NaN
# 1           2        1     Xavier Weaver       WR   23   R           NaN
# 2           3        1       Zach Pascal       WR   29   7           NaN
# 3           4        1       Chris Moore       WR   31   9           NaN
# 4           5        1         Zay Jones       WR   29   8           NaN
# ..        ...      ...               ...      ...  ...  ..           ...
# 57         58        1  Carter O'Donnell       OT   25   3             O
# 58         59        1   Christian Jones       OT   24   R             O
# 59         60        1        BJ Ojulari       LB   22   2             O
# 60         61        1   Darius Robinson       DE   23   R             O
# 61         62        1      Elijah Jones       CB   24   R             O
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# ...
